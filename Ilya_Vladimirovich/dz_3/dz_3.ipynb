# %% [markdown]
# ### Задание
#
# 1. Загрузить файл длиной не менее 2000 символов.
# 2. Составить программу, которая считает число уникальных слов в тексте (без критерия схожести)
# 3. Составить программу, которая считает число гласных и согласных букв.
# 4. Составить программу, которая считает число предложений, их длину и число (количество) раз использования каждого слова в тексте (с критерием схожести, критерий схожести слов выбрать самостоятельно, например, spacy (en_core_web_sm) или расстояние Левенштейна).
# 5. Вывести 10 наиболее часто встречаемых слов.
#
# p.s. Рекомендую перед решением задания проанализировать задачу и обосновать алгоритм ее решения в текстовом виде. В процессе написания кода использовать комментарии.

# %% [markdown]
# ### Анализ задания
#
# Для решения задачи требуется разделить задачу на несколько.
# * Токенизация. Для не структурированных текстов разделение текста на предложения может быть не тривиальной задачей т.к. предложение может заканчиваться на различные знаки (.!?), однако точка может встречаться в предложении, но не завершать его (например различные сокращения неапример Mr. Smith). Разделение предложения на слова так же не простая задача. Например некоторые слова могут писаться через дефисы и правило разделения на токены по небуквенным символам уже не подходит.
# * Лемматизация Это задача приведения слова в нормальную форму (единственное число, настоящее время и тд)
# * Убрать из статистики стоп слова которые не несут информации
# * Некоторые буквы в английском языке могут быть в некоторых случаях гластными а в некоторых согластными. Например Y: yes, yet, но many, only. Для упрощения задачи определим их однозначно в 1 из классов
#
# Для решения обеих задач я решил использовать библиотеку spacy. В качестве текста была выбрана речь Уинстона Черчилля
#
# ### Выводы:
# * Топ самых встречаемых слов не несут полезной информации и обычно отбрасываются (так называемые стоп слова)
# * Число гласных букв почти в 2 раза меньше согласных
# * Около 10% слов в тексте потребовалось привести к нормальной форме

# %% [markdown]
# Установка пакета Spacy:

# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in /home/itiv422/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: packaging>=20.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (24.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (0.13.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (59.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: jinja2 in /home/itiv422/.local/lib/python3.10/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: language-data>=1.2 in /home/itiv422/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/itiv422/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/itiv422/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/itiv422/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /home/itiv422/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/itiv422/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /home/itiv422/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/itiv422/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/itiv422/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/itiv422/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/itiv422/.local/lib/python3.10/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/itiv422/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/itiv422/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/itiv422/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/itiv422/.local/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/itiv422/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import spacy
from collections import Counter

nlp = spacy.load('en_core_web_sm')

def process_text(file_path):
    # Чтение текста из файла с автоматическим зыкрытием файла
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    doc = nlp(text)

    # Подсчет уникальных слов без лемматизации
    num_unique_words_no_lemma = len({token.text.lower() for token in doc if token.is_alpha})

    # Подсчет гласных и согласных
    vowels = "aeiou"
    consonants = "bcdfghjklmnpqrstvwxyz"
    num_vowels = len([char for char in text.lower() if char in vowels])
    num_consonants = len([char for char in text.lower() if char in consonants])

    # Подсчет предложений и их длины
    sentences = list(doc.sents)
    num_sentences = len(sentences)
    sentence_lengths = [len(sentence) for sentence in sentences]

    # Подсчет частоты использования каждого слова без стоп слов
    word_freq = Counter(token.lemma_.lower() for token in doc if token.is_alpha and not token.is_stop)
    sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)

   # Подсчет уникальных слов с лемматизацией
    num_unique_words_with_lemma = len(word_freq)

    # 10 наиболее часто встречаемых слов
    most_common_words = sorted_word_freq[:10]

    # Вывод результатов
    print(f"Число уникальных слов (без лемматизации): {num_unique_words_no_lemma}")
    print(f"Число уникальных слов (с лемматизацией): {num_unique_words_with_lemma}")
    print(f"Число гласных: {num_vowels}")
    print(f"Число согласных: {num_consonants}")
    print(f"Число предложений: {num_sentences}")
    print(f"Длины предложений: {sentence_lengths}")
    print("\n10 наиболее часто встречаемых слов:")
    for word, freq in most_common_words:
        print(f"{word}: {freq}")
    print("\nЧастота использования каждого слова:")
    for word, freq in sorted_word_freq:
        print(f"{word}: {freq}")


process_text("./text.txt")
# Out:
# Число уникальных слов (без лемматизации): 1378
# Число уникальных слов (с лемматизацией): 1065
# Число гласных: 8628
# Число согласных: 13627
# Число предложений: 181
# Длины предложений: [9, 22, 11, 9, 30, 24, 29, 60, 39, 37, 28, 10, 67, 14, 10, 17, 31, 13, 24, 38, 18, 30, 14, 15, 32, 57, 22, 34, 24, 36, 16, 33, 16, 23, 8, 33, 7, 43, 69, 36, 58, 15, 17, 16, 18, 28, 24, 14, 25, 15, 23, 45, 19, 35, 34, 27, 65, 40, 28, 36, 20, 27, 30, 68, 90, 15, 13, 16, 20, 18, 64, 65, 28, 7, 32, 11, 28, 32, 16, 15, 62, 36, 14, 29, 25, 27, 18, 13, 37, 41, 11, 25, 26, 32, 16, 29, 10, 24, 25, 11, 47, 9, 9, 77, 16, 63, 37, 10, 19, 60, 7, 7, 15, 34, 21, 38, 22, 15, 8, 26, 39, 20, 17, 68, 26, 38, 38, 23, 29, 37, 64, 58, 27, 13, 21, 30, 62, 39, 28, 15, 16, 31, 10, 13, 26, 7, 42, 33, 49, 14, 71, 35, 24, 32, 40, 28, 24, 22, 47, 10, 18, 35, 15, 24, 29, 47, 14, 25, 36, 31, 28, 37, 28, 47, 9, 63, 42, 120, 68, 13, 89]
#
# 10 наиболее часто встречаемых слов:
# world: 31
# war: 30
# united: 21
# time: 19
# states: 17
# country: 16
# british: 16
# power: 13
# organization: 13
# american: 12
#
# Частота использования каждого слова:
# world: 31
# war: 30
# united: 21
# time: 19
# states: 17
# country: 16
# british: 16
# power: 13
# organization: 13
# american: 12
# people: 12
# speak: 10
# work: 10
# europe: 10
# great: 10
# communist: 10
# year: 10
# come: 9
# shall: 9
# feel: 9
# future: 9
# nations: 9
# peace: 8
# fact: 8
# let: 8
# man: 8
# force: 8
# far: 8
# duty: 7
# nation: 7
# sure: 7
# freedom: 7
# strength: 7
# home: 7
# common: 7
# agreement: 7
# build: 7
# party: 7
# cause: 7
# soviet: 7
# russian: 7
# english: 6
# difficulty: 6
# grow: 6
# danger: 6
# government: 6
# friend: 6
# special: 6
# commonwealth: 6
# russia: 6
# large: 5
# day: 5
# democracy: 5
# purpose: 5
# happen: 5
# million: 5
