# %% [markdown]
# Задание 1

# %% [markdown]
# Цель:
# • Загрузить файл длиной не менее 2000 символов.
# • Составить программу, которая считает число уникальных слов в тексте (без критерия схожести)
# • Составить программу, которая считает число гласных и согласных букв.
# • Составить программу, которая считает число предложений, их длину и число (количество) раз использования каждого слова в тексте (с критерием схожести, критерий схожести слов выбрать самостоятельно, например, spacy (en_core_web_sm) или расстояние Левенштейна).
# • Вывести 10 наиболее часто встречаемых слов.

# %% [markdown]
# Необходимо составить программу, которая должна содержать следующие функции:
# • Функцию преобразования текста в список.
# • Функцию подсчета уникальных слов без критерия схожести.
# • Функцию подсчет гласных и согласных букв.
# • Функцию подсчета длины предложений в тексте и их размера в количестве слов.
# Целесообразно использовать регулярные выражения в функции подсчета слов для уменьшения объема кода и его упрощения.

# %% [markdown]
# Импортируем модуль регулярных выражений:

# %%
import re;

# %% [markdown]
# Реализуем функцию преобразования текста в список:

# %%
def words_list_creator(file):
    text = file.read();
    text = text.replace("\n", " ").replace(",", " ").replace(".", " ").replace("?", " ").replace("!", " ").replace("-", " ");
    text = text.lower();
    words = text.split();
    words_list = list(words);
    return words_list;

# %% [markdown]
# Реализуем функцию подсчета уникальных слов без критерия схожести:подсчета уникальных слов без критерия схожести

# %%
def uniq_words_counter(words_list):
    uniq_words = list();
    for word in words_list:
        if word in uniq_words:
            pass;
        else:
            uniq_words.append(word);
    return len(uniq_words);

# %% [markdown]
# Реализуем функцию подсчета количества гласных и согласных букв в словах:

# %%
def vowels_and_consonants_counter(words_list):
    string = str(words_list);
    vowels_list = ["а", "е", "ё", "и", "о", "у", "ы", "э", "ю", "я"];
    consonants_list = ["б", "в", "г", "д", "ж", "з", "й", "к", "л", "м", "н", "п", "р", "с", "т", "ф", "х", "ц", "х", "ш", "щ", "ч"];
    vowels_count = 0;
    consonants_count = 0;
    for letter in string:
        if letter in vowels_list:
            vowels_count +=1;
        if letter in consonants_list:
            consonants_count +=1;
    return [vowels_count, consonants_count];

# %% [markdown]
# Реализуем функцию подсчета количества предложений и их длины в количестве слов при помощи регулярных выражений:

# %%
def sentences_counter(file):
    text = file.read();
    sentences = re.findall(r"\s*([^.?!]+)\s*", text);
    sentence_count = 0;
    while sentence_count < len(sentences):
        sentence_string = str(sentences[sentence_count]);
        sentence_string = sentence_string.replace("\n", " ").replace(",", " ").replace(".", " ").replace("?", " ").replace("!", " ").replace("-", " ");
        sentence_string = sentence_string.lower();
        sentence_string_words = sentence_string.split();
        sentence_string_list = list(sentence_string_words);
        print(f"Длина предложения {sentence_count + 1}:", len(sentence_string_list), "слов(-а, -о)");
        sentence_count +=1;
    return len(sentences);

# %% [markdown]
# Загрузим текстовый файл объемом не менее 2000 символов и передадим его в ряд реализованных функций:

# %%
file = open('Chehov_Anton__Tolstyi_i_tonkii.txt', 'r', encoding = 'utf-8');
print(f"Число уникальных слов в тесте (без критерия схожести): {uniq_words_counter(words_list_creator(file))}");
file = open('Chehov_Anton__Tolstyi_i_tonkii.txt', 'r', encoding = 'utf-8');
print (f"Число гласных букв в тексте: {vowels_and_consonants_counter(words_list_creator(file))[0]}");
file = open('Chehov_Anton__Tolstyi_i_tonkii.txt', 'r', encoding = 'utf-8');
print (f"Число согласных букв в тексте: {vowels_and_consonants_counter(words_list_creator(file))[1]}");
file = open('Chehov_Anton__Tolstyi_i_tonkii.txt', 'r', encoding = 'utf-8');
print(f"Количество предложений в тексте: {sentences_counter(file)}");
# Out:
# Число уникальных слов в тесте (без критерия схожести): 341
# Число гласных букв в тексте: 1202
# Число согласных букв в тексте: 1620
# Длина предложения 1: 1 слов(-а, -о)
# Длина предложения 2: 19 слов(-а, -о)
# Длина предложения 3: 1 слов(-а, -о)
# Длина предложения 4: 1 слов(-а, -о)
# Длина предложения 5: 24 слов(-а, -о)
# Длина предложения 6: 15 слов(-а, -о)
# Длина предложения 7: 7 слов(-а, -о)
# Длина предложения 8: 14 слов(-а, -о)
# Длина предложения 9: 7 слов(-а, -о)
# Длина предложения 10: 20 слов(-а, -о)
# Длина предложения 11: 1 слов(-а, -о)
# Длина предложения 12: 4 слов(-а, -о)
# Длина предложения 13: 3 слов(-а, -о)
# Длина предложения 14: 2 слов(-а, -о)
# Длина предложения 15: 4 слов(-а, -о)
# Длина предложения 16: 1 слов(-а, -о)
# Длина предложения 17: 2 слов(-а, -о)
# Длина предложения 18: 1 слов(-а, -о)
# Длина предложения 19: 2 слов(-а, -о)
# Длина предложения 20: 3 слов(-а, -о)
# Длина предложения 21: 11 слов(-а, -о)
# Длина предложения 22: 4 слов(-а, -о)
# ...

# %% [markdown]
# Для решения задачи лемматизации требуется использовать библиотеку spaCy, а также заранее обученную модель "ru_core_news_sm".

# %% [markdown]
# Импортируем необходимые модули:

# %%
import glob;
import spacy;
from collections import Counter;

# %% [markdown]
# Реализуем код, который будет загружать файл объемом не менее 2000 символов, который, в свою очередь, будет разбиваться на токены, анализируемые предобученной моделью с учетом стоп-слов. Подсчет токенов реализован при помощи счетчика. Результат работы программы: 10 наиболее часто встречаемых символов и слов в тексте, а также количесвто уникальных слов с учетом критерия схожести.

# %%
nlp = spacy.load("ru_core_news_sm");
path = 'Chehov_Anton__Tolstyi_i_tonkii.txt';

for file in glob.glob(path):
    with open('Chehov_Anton__Tolstyi_i_tonkii.txt', encoding='utf-8', errors='ignore') as file_in:
        text = file_in.read();
        text_analysis = text.split();
        text_analysis = nlp(text);
        words = [token.text for token in text_analysis if not token.is_stop and not token.is_punct];
        word_freq = Counter(words);
        common_words = word_freq.most_common(10);
        print(f"10 Наиболее часто встречаемых слов и символов:", common_words);
        unique_words = [word for (word, freq) in word_freq.items() if freq == 1];
        print(f"Уникальных слов (с учетом критерия схожести):", len(unique_words));
# Out:
# 10 Наиболее часто встречаемых слов и символов: [('\n ', 21), ('\n', 6), ('тонкий', 6), ('Нафанаил', 6), ('Толстый', 5), ('жена', 4), ('детства', 4), ('хи', 4), ('Чехов', 3), ('Антон', 3)]
# Уникальных слов (с учетом критерия схожести): 227

# %% [markdown]
# Выводы:
# • В ходе задания были реализованы программы выполняющие цели, поставленные в начале работы.
# • Написанный код ведет подсчет предложений по критерию их разбиения символом ".", что приводит к ограничениям в виде чувствительности к сокращениям слов.
# • Лемматизация текста происходит с учетом символов переноса строки, что обусловлено ограничениями предобученной модели "ru_core_news_sm". На предобученной модели "en_core_web_sm" подобная проблема решаема.
