# %% [markdown]
# Цель: напишите программу, находящую наибольшее и наименьшее значение функции y = -26*x**2+25*x-9 на отрезке [-5,5]. Для решения используйте while и определенный размер шага (например 0.1). Найти производную и особую точку.

# %% [markdown]
# Импорт библиотек и их функций:

# %%
import array as arr
from sympy import diff, symbols, solve

# %% [markdown]
# Определение функции:

# %%
def equation_func (p_1, p_2, stp):
    
    """
    Функция находит значения функции на заданном интервале с заданным шагом, ее производную и точку экстремума функции
    Возвращает массив значений "y" функции от х, максимальное и минимальное значения функции, точку экстремума функции
    """
    
    y = arr.array('f', []); 
    x = float(p_1);
    print(f"Вычисление значений для функции вида y=-26*x(^2)+25*x-9 \n x:\t\t y:");
    while x <= p_2:
        t = -26 * x ** (2) + 25 * x - 9;
        y.append(t);
        print(f"{x:.2f}   {y[-1]:.2f}");
        x += stp; 
    max_y = max(y);
    min_y = min(y);
    print(f"Максимальное значение функции в интервале от {p_1:.2f} до {p_2:.2f}: {max_y:.2f}");
    print(f"Минимальное значение функции в интервале от {p_1:.2f} до {p_2:.2f}: {min_y:.2f}");
    x = symbols('x', real = True);
    diff_equation = diff(-26 * x ** (2) + 25 * x - 9, x);
    print(f"Частная производная первого порядка функции вида y=-26*x(^2)+25*x-9 равна: (d/dx)(-26*x(^2)+25*x-9) = {diff_equation}");
    critical_point = solve(diff_equation, x);
    print(f"Критическая точка функции: x = {critical_point}");
    return y, max_y, min_y, critical_point;

# %% [markdown]
# Программа для вычисления наибольшего и наименьшего значений функции.
# Начальное определение шага:

# %%
step = 0;

# %% [markdown]
# Конструкция try-except для проверки првильности ввода:

# %%
while step <= 0:
    try:        
        step = float(input("Введите шаг вычисления функции: "));
        if step <= 0:
            print("Шаг вычисления функции не может быть отрицательной величиной или равнятся нулю!");
    except:
        continue;
# Out:
# Введите шаг вычисления функции:  -1
# Шаг вычисления функции не может быть отрицательной величиной или равнятся нулю!
# Введите шаг вычисления функции:  0
# Шаг вычисления функции не может быть отрицательной величиной или равнятся нулю!
# Введите шаг вычисления функции:  0.1

# %% [markdown]
# Определение интервала определения функции:

# %%
point_1 = -5;
point_2 = 5;

# %% [markdown]
# Вызов функции:

# %%
equation_func(point_1, point_2, step);
# Out:
# Вычисление значений для функции вида y=-26*x(^2)+25*x-9
#  x:		 y:
# -5.00   -784.00
# -4.90   -755.76
# -4.80   -728.04
# -4.70   -700.84
# -4.60   -674.16
# -4.50   -648.00
# -4.40   -622.36
# -4.30   -597.24
# -4.20   -572.64
# -4.10   -548.56
# -4.00   -525.00
# -3.90   -501.96
# -3.80   -479.44
# -3.70   -457.44
# -3.60   -435.96
# -3.50   -415.00
# -3.40   -394.56
# -3.30   -374.64
# -3.20   -355.24
# -3.10   -336.36
# -3.00   -318.00
# -2.90   -300.16
# -2.80   -282.84
# -2.70   -266.04
# -2.60   -249.76
# -2.50   -234.00
# -2.40   -218.76
# -2.30   -204.04
# -2.20   -189.84
# -2.10   -176.16
# -2.00   -163.00
# -1.90   -150.36
# -1.80   -138.24
# -1.70   -126.64
# -1.60   -115.56
# -1.50   -105.00
# -1.40   -94.96
# -1.30   -85.44
# -1.20   -76.44
# -1.10   -67.96
# -1.00   -60.00
# -0.90   -52.56
# -0.80   -45.64
# -0.70   -39.24
# -0.60   -33.36
# -0.50   -28.00
# -0.40   -23.16
# -0.30   -18.84
# -0.20   -15.04
# -0.10   -11.76
# -0.00   -9.00
# 0.10   -6.76
# 0.20   -5.04
# 0.30   -3.84
# 0.40   -3.16
# 0.50   -3.00
# 0.60   -3.36
# 0.70   -4.24
# 0.80   -5.64
# 0.90   -7.56
# 1.00   -10.00
# 1.10   -12.96
# 1.20   -16.44
# 1.30   -20.44
# 1.40   -24.96
# 1.50   -30.00
# 1.60   -35.56
# 1.70   -41.64
# 1.80   -48.24
# 1.90   -55.36
# 2.00   -63.00
# 2.10   -71.16
# 2.20   -79.84
# 2.30   -89.04
# 2.40   -98.76
# 2.50   -109.00
# 2.60   -119.76
# 2.70   -131.04
# 2.80   -142.84
# 2.90   -155.16
# 3.00   -168.00
# 3.10   -181.36
# 3.20   -195.24
# 3.30   -209.64
# 3.40   -224.56
# 3.50   -240.00
# 3.60   -255.96
# 3.70   -272.44
# 3.80   -289.44
# 3.90   -306.96
# 4.00   -325.00
# 4.10   -343.56
# 4.20   -362.64
# 4.30   -382.24
# 4.40   -402.36
# 4.50   -423.00
# 4.60   -444.16
# 4.70   -465.84
# 4.80   -488.04
# 4.90   -510.76
# 5.00   -534.00
# Максимальное значение функции в интервале от -5.00 до 5.00: -3.00
# Минимальное значение функции в интервале от -5.00 до 5.00: -784.00
# Частная производная первого порядка функции вида y=-26*x(^2)+25*x-9 равна: (d/dx)(-26*x(^2)+25*x-9) = 25 - 52*x
# Критическая точка функции: x = [25/52]
