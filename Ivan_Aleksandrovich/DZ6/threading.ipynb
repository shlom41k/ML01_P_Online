# %% [markdown]
# Реализовать с использованием потоков и процессов скачивание файлов из интернета.
# Список файлов для скачивания подготовить самостоятельно (например изображений, не менее 100 изображений или других объектов). Сравнить производительность с последовательным методом. Сравнивть производительность Thread и multiprocessing решений. Попробовать подобрать оптимальное число потоков/процессов.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.onliner.by/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
image_tags = soup.find_all('img')
image_links = [img['src'] for img in image_tags if 'src' in img.attrs]
absolute_links = list(set([requests.compat.urljoin(url, link) for link in image_links])) # Делаем ссылки абсолютными и неповторяющимися

# %%
import urllib.request
import os
import time

dirname = "download"
file_path = os.makedirs(dirname, exist_ok=True)

def download (links, thread_number):
    
    for i, link in enumerate(links):
        try:
                response = requests.get(link)

                file_name = f"image_{i}_{thread_number}.jpg"
                if not file_name.endswith('.jpg'): 
                    file_name += '.jpg'
                save_path = os.path.join(dirname, file_name)

                with open(save_path, 'wb') as file:
                    file.write(response.content)

                print(f"Сохранено: {save_path}")
        except requests.RequestException as e:
            print(f"Ошибка при загрузке {link}: {e}")

# %%
start_time = time.time()
download (absolute_links)
end_time = time.time()

print(f"Время выполнения: {end_time - start_time} секунд")

# %%
import threading
def run_with_threads(num_threads):
    threads = []
    
    last_item = 0
    batch_size = (len(absolute_links)//num_threads)
    for i in range(num_threads):
        # Создаем поток для выполнения задачи
        
        thread = threading.Thread(target=download, args=(absolute_links[last_item:last_item+batch_size],i,))
        threads.append(thread)
       # thread.start()  # Запускаем поток
        last_item += batch_size
        
    for thread in threads:
        thread.start()

    
    # Ждем завершения всех потоков
    for thread in threads:
        thread.join()

# Цикл, который будет запускать код с разным количеством потоков
for num_threads in [8]:  # Можно изменить на любое количество
    print(f"\nЗапуск с {num_threads} потоками...")
    start_time = time.time()  # Засекаем время начала
    run_with_threads(num_threads)
    end_time = time.time()  # Засекаем время окончания
    print(f"Время выполнения с {num_threads} потоками: {end_time - start_time} секунд")
# Out:
# Запуск с 8 потоками...
# Сохранено: download\image_0_1.jpg
# Сохранено: download\image_0_0.jpg
# Сохранено: download\image_0_3.jpg
# Сохранено: download\image_0_2.jpg
# Сохранено: download\image_0_5.jpg
# Сохранено: download\image_0_6.jpg
# Сохранено: download\image_0_4.jpg
# Сохранено: download\image_1_1.jpg
# Сохранено: download\image_0_7.jpg
# Сохранено: download\image_1_0.jpg
# Сохранено: download\image_1_5.jpg
# Сохранено: download\image_1_4.jpg
# Сохранено: download\image_1_3.jpg
# Сохранено: download\image_1_2.jpg
# Сохранено: download\image_2_1.jpg
# Сохранено: download\image_1_6.jpg
# Сохранено: download\image_1_7.jpg
# Сохранено: download\image_2_5.jpg
# Сохранено: download\image_2_0.jpg
# Сохранено: download\image_2_3.jpg
# Сохранено: download\image_2_2.jpg
# Сохранено: download\image_3_1.jpg
# Сохранено: download\image_2_4.jpg
# Сохранено: download\image_2_6.jpg
# Сохранено: download\image_2_7.jpg
# Сохранено: download\image_3_0.jpg
# Сохранено: download\image_3_3.jpg
# Сохранено: download\image_3_2.jpg
# Сохранено: download\image_3_5.jpg
# Сохранено: download\image_4_1.jpg
# Сохранено: download\image_3_7.jpg
# Сохранено: download\image_4_0.jpg
# Сохранено: download\image_4_7.jpg
# Сохранено: download\image_4_2.jpg
# Сохранено: download\image_3_4.jpg
# Сохранено: download\image_3_6.jpg
# Сохранено: download\image_4_3.jpg
# Сохранено: download\image_5_1.jpg
# Сохранено: download\image_4_5.jpg
# Сохранено: download\image_5_0.jpg
# Сохранено: download\image_5_2.jpg
# Сохранено: download\image_5_7.jpg
# Сохранено: download\image_4_6.jpg
# Сохранено: download\image_5_3.jpg
# Сохранено: download\image_5_5.jpg
# Сохранено: download\image_4_4.jpg
# Сохранено: download\image_6_0.jpg
# Сохранено: download\image_6_1.jpg
# Сохранено: download\image_5_6.jpg
# Сохранено: download\image_6_5.jpg
# Сохранено: download\image_5_4.jpg
# Сохранено: download\image_7_0.jpg
# Сохранено: download\image_6_7.jpg
# Сохранено: download\image_6_3.jpg
# Сохранено: download\image_6_2.jpg
# Сохранено: download\image_7_1.jpg
# Сохранено: download\image_7_2.jpg
# Сохранено: download\image_7_5.jpg
# Сохранено: download\image_7_7.jpg
# Сохранено: download\image_8_0.jpg
# Сохранено: download\image_6_4.jpg
# Сохранено: download\image_7_3.jpg
# Сохранено: download\image_6_6.jpg
# Сохранено: download\image_8_1.jpg
# Сохранено: download\image_8_5.jpg
# Сохранено: download\image_7_4.jpg
# Сохранено: download\image_8_3.jpg
# Сохранено: download\image_9_0.jpg
# Сохранено: download\image_8_7.jpg
# Сохранено: download\image_8_2.jpg
# Сохранено: download\image_7_6.jpg
# Сохранено: download\image_10_0.jpg
# Сохранено: download\image_9_5.jpg
# Сохранено: download\image_8_6.jpg
# Сохранено: download\image_9_1.jpg
# Сохранено: download\image_9_2.jpg
# Сохранено: download\image_9_7.jpg
# Сохранено: download\image_9_3.jpg
# Сохранено: download\image_11_0.jpg
# Сохранено: download\image_10_5.jpg
# Сохранено: download\image_10_1.jpg
# Сохранено: download\image_9_6.jpg
# Сохранено: download\image_10_7.jpg
# Сохранено: download\image_12_0.jpg
# Сохранено: download\image_10_6.jpg
# Сохранено: download\image_10_2.jpg
# Сохранено: download\image_11_5.jpg
# Сохранено: download\image_11_1.jpg
# Сохранено: download\image_10_3.jpg
# Сохранено: download\image_11_7.jpg
# Сохранено: download\image_13_0.jpg
# Сохранено: download\image_12_1.jpg
# Сохранено: download\image_11_6.jpg
# Сохранено: download\image_11_2.jpg
# Сохранено: download\image_13_1.jpg
# Сохранено: download\image_14_0.jpg
# Сохранено: download\image_8_4.jpg
# Сохранено: download\image_12_7.jpg
# Сохранено: download\image_12_6.jpg
# Сохранено: download\image_12_2.jpg
# Сохранено: download\image_14_1.jpg
# Сохранено: download\image_9_4.jpg
# Сохранено: download\image_11_3.jpg
# Сохранено: download\image_12_5.jpg
# Сохранено: download\image_15_0.jpg
# Сохранено: download\image_13_7.jpg
# Сохранено: download\image_13_6.jpg
# Сохранено: download\image_13_2.jpg
# Сохранено: download\image_15_1.jpg
# Сохранено: download\image_12_3.jpg
# Сохранено: download\image_13_5.jpg
# Сохранено: download\image_14_7.jpg
# Сохранено: download\image_10_4.jpg
# Сохранено: download\image_14_6.jpg
# Сохранено: download\image_14_2.jpg
# Сохранено: download\image_11_4.jpg
# Сохранено: download\image_13_3.jpg
# Сохранено: download\image_14_5.jpg
# Сохранено: download\image_15_2.jpg
# Сохранено: download\image_15_7.jpg
# Сохранено: download\image_12_4.jpg
# Сохранено: download\image_15_6.jpg
# Сохранено: download\image_13_4.jpg
# Сохранено: download\image_14_4.jpg
# Сохранено: download\image_15_5.jpg
# Сохранено: download\image_15_4.jpg
# Сохранено: download\image_14_3.jpg
# Сохранено: download\image_15_3.jpg
# Время выполнения с 8 потоками: 1.9199442863464355 секунд
