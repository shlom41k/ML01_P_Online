# %% [markdown]
# Цель: изучить работу гита и научиться решать конфликты.
#
# Здание: создать ситуацию когда при слиянии веток случился конфликт и разрешить его.
#
# Разрешил через VCS
#
# ![Conflict.png](attachment:Conflict.png)
# ![Branches.png](attachment:Branches.png)
