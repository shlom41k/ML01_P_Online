# %% [markdown]
# ## Задание:

# %% [markdown]
# * Загрузить файл длиной не менее 2000 символов.
# * Составить программу, которая считает число уникальных слов в тексте (без критерия схожести)
# * Составить программу, которая считает число гласных и согласных букв.
# * Составить программу, которая считает число предложений, их длину и число (количество) раз использования
#     каждого слова в тексте (с критерием схожести, критерий схожести слов выбрать самостоятельно,
#     например, spacy (en_core_web_sm) или расстояние Левенштейна).
# * Вывести 10 наиболее часто встречаемых слов.

# %% [markdown]
# ### _Для решения поставленной задачи будем использовать готовую библиотеку ***spacy***. Данная библиотека предоставляет мощный готовый инструмент для обработки текстовых данных._

# %% [markdown]
# ### 1. Подключаем необходимые библиотеки и импортируем необходимые методы и функции:
# Для решения задачи необходимо:
# - библиотека `spacy`;
# - функция чтения данных из файла `read_data` (описана в модуле `hw_03.py`);
# - список гласных и согласных букв алфавита (находятся в словаре `alphabet` модуля `settings`);
# - класс `Counter` модуля `collections` для удобства подсчета количества появлений элементов в последовательностях.

# %%
import spacy
from hw_03 import read_data
from settings import alphabet
from collections import Counter

# %% [markdown]
# ### 2. Считываем анализируемый текст из файла:

# %%
f = "../data/test_data_01.txt"
text = read_data(f)

print(f"Исходный текст файла '{f}:'\n")
print(text)
# Out:
# Исходный текст файла '../data/test_data_01.txt:'
#
# International cooperation in the sphere of science and technology.
#
# Belarusian science aims at resourcesaving, energy-efficient technologies, industrial biotechnologies, nanomaterials, environmental protection and information solutions. Different research and development centres contribute to the innovation infrastructure of the Republic of Belarus. The two biggest scientific centres in our country are the National Academy of Sciences of Belarus (NASB) and the High-Tech Park (HTP). Our scientists can be proud of their achievements as they contribute a lot to the development of the world's science.
# Belarusian scientists of the National Centre of Particle and Hi-Energy Physics of the Belarusian State University took part in experiments at the Large Hadron Collider in the European Organization for Nuclear Research (CERN) which is located at the France-Switzerland border. Our scientists controlled the operation of the Compact Muon Solenoid (CMS).
# Belarusian physicists created the source of terahertz radiation which helps to make different objects visible while they are inside solid or liquid bodies.
# Our scientists grew a red emerald for the first time in the world. This kind of emerald is very rare in nature, and the artificial analogue created by Belarusian scientists is 100 times cheaper.
# Belarusian scientists also created an electronic system "ForestFire" to determine the level of radioactive contamination after forest fires this innovation helps to model possible situations and to find possible solutions during and after forest fires.
# Belarusian agriculturists grew new kinds of potato and wheat!
# Our scientists created a brand new-generation laser which can be used in different industries from medicine to the manufacturing sector. This laser is smaller, safer for eyes and more functional than its foreign analogues.
# Belarus with its scientific potential is now called the Silicon Valley of Europe. The High-Tech Park of Belarus, one of the leading innovation-based IT clusters in Europe, appeared in 2006. The software produced by the HTP resident companies is in high demand abroad and is used by Coca-Cola, Microsoft, Google, Toyota, MTV, Reuters, Samsung, Mitsubishi, British Telecom and the World Bank. In 2011 six resident companies of the HTP were included in the "WORLD Top-100 Providers of IT Services" list. Our country is also number 1 IT technologies exporter within the CIS.
# Belarusian company OAO "Peleng" is one of the leading developers of optical devices and optoelectronic systems for military and dual use. The company produces exclusive space equipment. On July 22, 2012 the Belarusian satellite for the remote sensing of the Earth was launched into outer space. This satellite is a part of a cluster of five satellites by the "Soyuz-FG" booster rocket from the Baikonur space launch site. The Belarusian satellite can relocate in the orbit and take images at the required angle. The satellite is fitted with the equipment produced by OAO "Peleng" and works jointly with the Russian satellite "Canopus-B". Peleng also created a "SKIF-GRID" supercomputer on the basis of 12-core AMD Opteron processor and graphic processing units.
# Belarus takes an active part in the International telecommunications, information and banking technologies forum TIBO, Belarus' biggest IT forum and one of the major events in the sphere of telecommunications and software in the Baltic States and the CIS. The participants from Belarus, Russia, Europe, Latin America and Asia present the most interesting media projects and modern mass media technologies. The program of the forum includes master classes of famous media persons and presentations of periodicals, TV channels, radio channels and websites. Belarusian scientists presented a unique innovation at the international forum TIBO-2015. A unique chip can help both experts and ordinary buyers to learn all the product information in a flash. Such electronic passports have already been tested by Belarusian producers and buyers of expensive fur products. In a minute, you can see a full file on the chosen product on the screen of your mobile phone. You can learn the quality and origin of the product, place of production and other information.
# Annually about 450 international science and technology projects are implemented in Belarus. Some of these projects have bilateral character. Belarus supports bi-lateral cooperation with Russia, Latvia and Lithuania, Ukraine, Poland, Moldova, Kazakhstan, Serbia, China, India, Venezuela and most of them are hosted by the Scientific and Technological Park "Polytechnic" at Belarusian National Technical University. Belarus-South Korean scientific centre is hosted by the NASB.
# Among the two most successful bilateral IT achievements are Viber and World of Tanks (WoT).
# Viber is the most recognizable Belarusian brand in the IT sector? Viber is called "a Belarusian miracle". This is an instant messaging and voice over IP application for smartphones. With the help of Viber you can exchange video and audio messages. Viber Media Company was founded by Israeli-Belarusian partners Talmon Marko and Igor Magazinnik. The company is run from Israel but has its development centres in Belarus. The company started in 2010 as a small development firm of 40 people and its founder Sergei Goncharic. Nowadays Viber is the leader of social applications category in the Appstores in 30 countries. Viber has about 280 million global registered users.
# Another famous Belarusian IT company is Belarusian-Cypriot company "Wargaming" with its massively multiplayer online game "World of Tanks". The developer of WoT "Game Stream", Minsk Development Centre of Wargaming, is a resident company of the High-Tech Park in Belarus. Game Stream provides IT support in organizing international events. The game was officially announced in 2009 and in August 2010 the Russian version of the game was officially released. The players can choose six primary types of battles and take control of a single armoured vehicle and they can communicate with other players through typing or voice chat. In 2011 the number of WoT users reached 1 million. In January 2011 the world record "The Most Players Online Simultaneously" was officially registered by the Guinness Book of Records (91,311 players). In 2012 the game was improved and new features and vehicles were added. Also in 2012 WoT debuted as an eSports game at the World Cyber Games. In 2013 and 2014 WoT was named the "Online Game of the Year" and got the "Golden Joystick Award". Today the number of WoT fans exceeds more than 100 million.
# Belarus also has its own Nobel Prize winner in Science. Zhores Ivanovich Alferov was born on March 15, 1930 in Vitebsk, Belarus to a family of a factory manager. He finished high school in Minsk and in 1947 entered Belarusian Politechnic Academy. In 1952 Alferov graduated from Leningrad Electrotechnical Institute and began to work in the Ioffe Physico-Technical Institute where he got several scientific degrees. In 1987 Zhores Alferov became the Director of the Institute. Alferov invented the heterotransistor which revolutionized the mobile phone and satellite communications. This in turn improved semiconductor design in LEDs and CDs. In 2000 Zhores Alferov received the Nobel Prize in Physics together with Herbert Kroemer and Jack Kilby for their work that laid the foundation for the modern era of information technology. Alferov's invention made it possible to transfer all the information from satellites down to the Earth and have many telephone lines between cities. We use his scientific innovations in our everyday life: in mobile phones, CDs, traffic lights, price tag's decoders and even lasers.

# %% [markdown]
# ### 3. Загружаем языковую модель библиотеки _**spacy**_:

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### 4. Применяем токенизацию (разбиение текста на слова, пунктуацию, спец. символы):

# %%
doc = nlp(text)

# %% [markdown]
# ### 5. Выполняем поиск слов в тексте (отбрасываем пунктуацию, символы переноса строки и др., стоп-слова):

# %%
unique_words = set(word.text.lower() for word in doc if (word.is_alpha and not word.is_stop))

print(f"Список 'уникальных' слов (без учета критерия схожести) - всего {len(unique_words)} слов:\n")
print(*unique_words)
# Out:
# Список 'уникальных' слов (без учета критерия схожести) - всего 445 слов:
#
# semiconductor determine invention graduated presentations media source cypriot science august visible sensing liquid work grid radioactive igor products demand zhores social basis small polytechnic politechnic presented experts minute mobile wheat industries game ivanovich debuted new brand dual finished typing present company winner centre features family classes phones ordinary required fg aims place recognizable smaller infrastructure america projects march nanomaterials sergei artificial price bodies mitsubishi created level cds israeli core resident supports jack services ukraine b satellites design participants character valley nobel solenoid era periodicals find major electrotechnical information persons sector images produced magazinnik contribute cms flash time venezuela htp coca launch asia quality organizing satellite eyes production analogues vehicles academy site forest model latvia ip forestfire players lithuania grew lines founded reached sciences software invented number particle hadron factory companies events hosted successful banking contamination developer included ioffe fitted supercomputer collider kroemer exclusive rare screen audio communications european battles cyber lights began jointly generation google abroad equipment biggest resourcesaving book year developers websites games turn voice peleng telecommunications award appeared global golden telecom joystick use solid russia buyers alferov mass sphere forum organization protection cheaper list optical physicists vehicle fires everyday wot started kind simultaneously smartphones talmon military development single fur famous version partners chosen school medicine leading india large latin states angle exceeds radiation marko samsung providers chat moldova system cis help improved analogue appstores technology received radio france tibo director provides innovations international implemented launched safer foreign instant multiplayer application solutions systems kinds centres microsoft wargaming compact kazakhstan esports interesting tested origin china announced park british registered emerald physico named national fans relocate takes potato today cluster agriculturists nowadays soyuz cooperation earth belarus potential control muon belarusian red applications category high efficient russian run nasb achievements controlled minsk energy released phone exporter scientific border amd channels silicon processor telephone cities leader vitebsk different primary israel born herbert innovation institute expensive master called space poland tv remote world heterotransistor support stream environmental file university based state traffic optoelectronic got revolutionized tag switzerland baikonur foundation product south objects million life bilateral online record chip outer laid scientists transfer clusters manager program canopus viber messages operation passports lateral technologies lasers skif leds serbia mtv processing units took inside tanks learn country massively oao devices laser cola electronic annually helps toyota rocket graphic firm hi technical goncharic added exchange technological messaging decoders bank founder entered reuters opteron active january bi countries nature tech orbit communicate modern people prize korean cern times biotechnologies republic records proud users works july possible video physics officially europe located guinness armoured research lot types degrees functional leningrad nuclear kilby booster choose unique terahertz produces manufacturing includes baltic producers industrial experiments miracle situations

# %% [markdown]
# ### 6. Выполняем подсчет количества гласных и согласных букв в исходном тексте:

# %%
vowels, consonants = 0, 0
for letter in text:
    if letter.lower() in alphabet.get("EN").get("vowels"):
        vowels += 1
    elif letter.lower() in alphabet.get("EN").get("consonants"):
        consonants +=1
        
print(f"Количество гласных букв: {vowels}; согласных букв: {consonants}.")
# Out:
# Количество гласных букв: 2457; согласных букв: 3789.

# %% [markdown]
# ### 7. Выполняем подсчет количества предложений в тексте и выводим информацию о их длине:

# %%
sentences = [str(sent).strip() for sent in doc.sents]
print(f"Количество предложений в тексте: {len(sentences)}.")

for ind, sent in enumerate(sentences):
    print(f"\tПредложение №{ind}: length: {len(sent)}; data: {sent}")
# Out:
# Количество предложений в тексте: 69.
# 	Предложение №0: length: 66; data: International cooperation in the sphere of science and technology.
# 	Предложение №1: length: 168; data: Belarusian science aims at resourcesaving, energy-efficient technologies, industrial biotechnologies, nanomaterials, environmental protection and information solutions.
# 	Предложение №2: length: 114; data: Different research and development centres contribute to the innovation infrastructure of the Republic of Belarus.
# 	Предложение №3: length: 134; data: The two biggest scientific centres in our country are the National Academy of Sciences of Belarus (NASB) and the High-Tech Park (HTP).
# 	Предложение №4: length: 117; data: Our scientists can be proud of their achievements as they contribute a lot to the development of the world's science.
# 	Предложение №5: length: 275; data: Belarusian scientists of the National Centre of Particle and Hi-Energy Physics of the Belarusian State University took part in experiments at the Large Hadron Collider in the European Organization for Nuclear Research (CERN) which is located at the France-Switzerland border.
# 	Предложение №6: length: 75; data: Our scientists controlled the operation of the Compact Muon Solenoid (CMS).
# 	Предложение №7: length: 155; data: Belarusian physicists created the source of terahertz radiation which helps to make different objects visible while they are inside solid or liquid bodies.
# 	Предложение №8: length: 66; data: Our scientists grew a red emerald for the first time in the world.
# 	Предложение №9: length: 127; data: This kind of emerald is very rare in nature, and the artificial analogue created by Belarusian scientists is 100 times cheaper.
# 	Предложение №10: length: 252; data: Belarusian scientists also created an electronic system "ForestFire" to determine the level of radioactive contamination after forest fires this innovation helps to model possible situations and to find possible solutions during and after forest fires.
# 	Предложение №11: length: 61; data: Belarusian agriculturists grew new kinds of potato and wheat!
# 	Предложение №12: length: 136; data: Our scientists created a brand new-generation laser which can be used in different industries from medicine to the manufacturing sector.
# 	Предложение №13: length: 85; data: This laser is smaller, safer for eyes and more functional than its foreign analogues.
# 	Предложение №14: length: 81; data: Belarus with its scientific potential is now called the Silicon Valley of Europe.
# 	Предложение №15: length: 107; data: The High-Tech Park of Belarus, one of the leading innovation-based IT clusters in Europe, appeared in 2006.
# 	Предложение №16: length: 200; data: The software produced by the HTP resident companies is in high demand abroad and is used by Coca-Cola, Microsoft, Google, Toyota, MTV, Reuters, Samsung, Mitsubishi, British Telecom and the World Bank.
# 	Предложение №17: length: 109; data: In 2011 six resident companies of the HTP were included in the "WORLD Top-100 Providers of IT Services" list.
# 	Предложение №18: length: 69; data: Our country is also number 1 IT technologies exporter within the CIS.
# 	Предложение №19: length: 137; data: Belarusian company OAO "Peleng" is one of the leading developers of optical devices and optoelectronic systems for military and dual use.
# 	Предложение №20: length: 47; data: The company produces exclusive space equipment.
# 	Предложение №21: length: 108; data: On July 22, 2012 the Belarusian satellite for the remote sensing of the Earth was launched into outer space.
# 	Предложение №22: length: 126; data: This satellite is a part of a cluster of five satellites by the "Soyuz-FG" booster rocket from the Baikonur space launch site.
# 	Предложение №23: length: 89; data: The Belarusian satellite can relocate in the orbit and take images at the required angle.
# 	Предложение №24: length: 125; data: The satellite is fitted with the equipment produced by OAO "Peleng" and works jointly with the Russian satellite "Canopus-B".
# 	Предложение №25: length: 123; data: Peleng also created a "SKIF-GRID" supercomputer on the basis of 12-core AMD Opteron processor and graphic processing units.
# 	Предложение №26: length: 255; data: Belarus takes an active part in the International telecommunications, information and banking technologies forum TIBO, Belarus' biggest IT forum and one of the major events in the sphere of telecommunications and software in the Baltic States and the CIS.
# 	Предложение №27: length: 149; data: The participants from Belarus, Russia, Europe, Latin America and Asia present the most interesting media projects and modern mass media technologies.
# 	Предложение №28: length: 148; data: The program of the forum includes master classes of famous media persons and presentations of periodicals, TV channels, radio channels and websites.
# 	Предложение №29: length: 89; data: Belarusian scientists presented a unique innovation at the international forum TIBO-2015.
# 	Предложение №30: length: 104; data: A unique chip can help both experts and ordinary buyers to learn all the product information in a flash.
# 	Предложение №31: length: 112; data: Such electronic passports have already been tested by Belarusian producers and buyers of expensive fur products.
# 	Предложение №32: length: 94; data: In a minute, you can see a full file on the chosen product on the screen of your mobile phone.
# 	Предложение №33: length: 95; data: You can learn the quality and origin of the product, place of production and other information.
# 	Предложение №34: length: 92; data: Annually about 450 international science and technology projects are implemented in Belarus.
# 	Предложение №35: length: 48; data: Some of these projects have bilateral character.
# 	Предложение №36: length: 272; data: Belarus supports bi-lateral cooperation with Russia, Latvia and Lithuania, Ukraine, Poland, Moldova, Kazakhstan, Serbia, China, India, Venezuela and most of them are hosted by the Scientific and Technological Park "Polytechnic" at Belarusian National Technical University.
# 	Предложение №37: length: 61; data: Belarus-South Korean scientific centre is hosted by the NASB.
# 	Предложение №38: length: 91; data: Among the two most successful bilateral IT achievements are Viber and World of Tanks (WoT).
# 	Предложение №39: length: 65; data: Viber is the most recognizable Belarusian brand in the IT sector?
# 	Предложение №40: length: 39; data: Viber is called "a Belarusian miracle".
# 	Предложение №41: length: 75; data: This is an instant messaging and voice over IP application for smartphones.
# 	Предложение №42: length: 65; data: With the help of Viber you can exchange video and audio messages.
# 	Предложение №43: length: 96; data: Viber Media Company was founded by Israeli-Belarusian partners Talmon Marko and Igor Magazinnik.
# 	Предложение №44: length: 74; data: The company is run from Israel but has its development centres in Belarus.
# 	Предложение №45: length: 102; data: The company started in 2010 as a small development firm of 40 people and its founder Sergei Goncharic.
# 	Предложение №46: length: 94; data: Nowadays Viber is the leader of social applications category in the Appstores in 30 countries.
# 	Предложение №47: length: 52; data: Viber has about 280 million global registered users.
# 	Предложение №48: length: 139; data: Another famous Belarusian IT company is Belarusian-Cypriot company "Wargaming" with its massively multiplayer online game "World of Tanks".
# 	Предложение №49: length: 130; data: The developer of WoT "Game Stream", Minsk Development Centre of Wargaming, is a resident company of the High-Tech Park in Belarus.
# 	Предложение №50: length: 67; data: Game Stream provides IT support in organizing international events.
# 	Предложение №51: length: 117; data: The game was officially announced in 2009 and in August 2010 the Russian version of the game was officially released.
# 	Предложение №52: length: 171; data: The players can choose six primary types of battles and take control of a single armoured vehicle and they can communicate with other players through typing or voice chat.
# 	Предложение №53: length: 50; data: In 2011 the number of WoT users reached 1 million.
# 	Предложение №54: length: 149; data: In January 2011 the world record "The Most Players Online Simultaneously" was officially registered by the Guinness Book of Records (91,311 players).
# 	Предложение №55: length: 71; data: In 2012 the game was improved and new features and vehicles were added.
# 	Предложение №56: length: 69; data: Also in 2012 WoT debuted as an eSports game at the World Cyber Games.
# 	Предложение №57: length: 97; data: In 2013 and 2014 WoT was named the "Online Game of the Year" and got the "Golden Joystick Award".
# 	Предложение №58: length: 59; data: Today the number of WoT fans exceeds more than 100 million.
# 	Предложение №59: length: 55; data: Belarus also has its own Nobel Prize winner in Science.
# 	Предложение №60: length: 105; data: Zhores Ivanovich Alferov was born on March 15, 1930 in Vitebsk, Belarus to a family of a factory manager.
# 	Предложение №61: length: 84; data: He finished high school in Minsk and in 1947 entered Belarusian Politechnic Academy.
# 	Предложение №62: length: 167; data: In 1952 Alferov graduated from Leningrad Electrotechnical Institute and began to work in the Ioffe Physico-Technical Institute where he got several scientific degrees.
# 	Предложение №63: length: 60; data: In 1987 Zhores Alferov became the Director of the Institute.
# 	Предложение №64: length: 105; data: Alferov invented the heterotransistor which revolutionized the mobile phone and satellite communications.
# 	Предложение №65: length: 59; data: This in turn improved semiconductor design in LEDs and CDs.
# 	Предложение №66: length: 189; data: In 2000 Zhores Alferov received the Nobel Prize in Physics together with Herbert Kroemer and Jack Kilby for their work that laid the foundation for the modern era of information technology.
# 	Предложение №67: length: 148; data: Alferov's invention made it possible to transfer all the information from satellites down to the Earth and have many telephone lines between cities.
# 	Предложение №68: length: 132; data: We use his scientific innovations in our everyday life: in mobile phones, CDs, traffic lights, price tag's decoders and even lasers.

# %% [markdown]
# ### 8. Выполняем подсчет числа повторений каждого слова в тексте (с учетом критерия схожести):
# Используется параметр `lemma_` слова (норм. форма) и `_Counter_` из модуля `_collections_`.

# %%
words_stat = Counter(word.lemma_.lower() for word in doc if (word.is_alpha and not word.is_stop))
print(f"Информация о частоте использования каждого слова в тексте:")

for word, cnt in words_stat.items():
    print(f"\tWord: '{word}': number of entries: {cnt}.")
# Out:
# Информация о частоте использования каждого слова в тексте:
# 	Word: 'international': number of entries: 5.
# 	Word: 'cooperation': number of entries: 2.
# 	Word: 'sphere': number of entries: 2.
# 	Word: 'science': number of entries: 5.
# 	Word: 'technology': number of entries: 7.
# 	Word: 'belarusian': number of entries: 19.
# 	Word: 'aim': number of entries: 1.
# 	Word: 'resourcesaving': number of entries: 1.
# 	Word: 'energy': number of entries: 2.
# 	Word: 'efficient': number of entries: 1.
# 	Word: 'industrial': number of entries: 1.
# 	Word: 'biotechnology': number of entries: 1.
# 	Word: 'nanomaterial': number of entries: 1.
# 	Word: 'environmental': number of entries: 1.
# 	Word: 'protection': number of entries: 1.
# 	Word: 'information': number of entries: 6.
# 	Word: 'solution': number of entries: 2.
# 	Word: 'different': number of entries: 3.
# 	Word: 'research': number of entries: 2.
# 	Word: 'development': number of entries: 5.
# 	Word: 'centre': number of entries: 6.
# 	Word: 'contribute': number of entries: 2.
# 	Word: 'innovation': number of entries: 5.
# 	Word: 'infrastructure': number of entries: 1.
# 	Word: 'republic': number of entries: 1.
# 	Word: 'belarus': number of entries: 14.
# 	Word: 'big': number of entries: 2.
# 	Word: 'scientific': number of entries: 6.
# 	Word: 'country': number of entries: 3.
# 	Word: 'national': number of entries: 3.
# 	Word: 'academy': number of entries: 2.
# 	Word: 'sciences': number of entries: 1.
# 	Word: 'nasb': number of entries: 2.
# 	Word: 'high': number of entries: 5.
# 	Word: 'tech': number of entries: 3.
# 	Word: 'park': number of entries: 4.
# 	Word: 'htp': number of entries: 3.
# 	Word: 'scientist': number of entries: 8.
# 	Word: 'proud': number of entries: 1.
# 	Word: 'achievement': number of entries: 2.
# 	Word: 'lot': number of entries: 1.
# 	Word: 'world': number of entries: 8.
# 	Word: 'particle': number of entries: 1.
# 	Word: 'hi': number of entries: 1.
# 	Word: 'physics': number of entries: 2.
# 	Word: 'state': number of entries: 1.
# 	Word: 'university': number of entries: 2.
# 	Word: 'take': number of entries: 2.
# 	Word: 'experiment': number of entries: 1.
# 	Word: 'large': number of entries: 1.
# 	Word: 'hadron': number of entries: 1.
# 	Word: 'collider': number of entries: 1.
# 	Word: 'european': number of entries: 1.
# 	Word: 'organization': number of entries: 1.
# 	Word: 'nuclear': number of entries: 1.
# 	Word: 'cern': number of entries: 1.
# 	Word: 'locate': number of entries: 1.
# 	Word: 'france': number of entries: 1.
# 	Word: 'switzerland': number of entries: 1.
# 	Word: 'border': number of entries: 1.
# 	Word: 'control': number of entries: 2.
# 	Word: 'operation': number of entries: 1.
# 	Word: 'compact': number of entries: 1.
# 	Word: 'muon': number of entries: 1.
# 	Word: 'solenoid': number of entries: 1.
# 	Word: 'cms': number of entries: 1.
# 	Word: 'physicist': number of entries: 1.
# 	Word: 'create': number of entries: 5.
# 	Word: 'source': number of entries: 1.
# 	Word: 'terahertz': number of entries: 1.
# 	Word: 'radiation': number of entries: 1.
# 	Word: 'help': number of entries: 4.
# 	Word: 'object': number of entries: 1.
# 	Word: 'visible': number of entries: 1.
# 	Word: 'inside': number of entries: 1.
# 	Word: 'solid': number of entries: 1.
# 	Word: 'liquid': number of entries: 1.
# 	Word: 'body': number of entries: 1.
# 	Word: 'grow': number of entries: 2.
# 	Word: 'red': number of entries: 1.
# 	Word: 'emerald': number of entries: 2.
# 	Word: 'time': number of entries: 2.
# 	Word: 'kind': number of entries: 2.
# 	Word: 'rare': number of entries: 1.
# 	Word: 'nature': number of entries: 1.
# 	Word: 'artificial': number of entries: 1.
# 	Word: 'analogue': number of entries: 2.
# 	Word: 'cheap': number of entries: 1.
# 	Word: 'electronic': number of entries: 2.
# 	Word: 'system': number of entries: 2.
# 	Word: 'forestfire': number of entries: 1.
# 	Word: 'determine': number of entries: 1.
# 	Word: 'level': number of entries: 1.
# 	Word: 'radioactive': number of entries: 1.
# 	Word: 'contamination': number of entries: 1.
# 	Word: 'forest': number of entries: 2.
# 	Word: 'fire': number of entries: 2.
# 	Word: 'model': number of entries: 1.
# 	Word: 'possible': number of entries: 3.
# 	Word: 'situation': number of entries: 1.
# 	Word: 'find': number of entries: 1.
# 	Word: 'agriculturist': number of entries: 1.
# 	Word: 'new': number of entries: 3.
# 	Word: 'potato': number of entries: 1.
# 	Word: 'wheat': number of entries: 1.
# 	Word: 'brand': number of entries: 2.
# 	Word: 'generation': number of entries: 1.
# 	Word: 'laser': number of entries: 3.
# 	Word: 'industry': number of entries: 1.
# 	Word: 'medicine': number of entries: 1.
# 	Word: 'manufacturing': number of entries: 1.
# 	Word: 'sector': number of entries: 2.
# 	Word: 'small': number of entries: 2.
# 	Word: 'safe': number of entries: 1.
# 	Word: 'eye': number of entries: 1.
# 	Word: 'functional': number of entries: 1.
# 	Word: 'foreign': number of entries: 1.
# 	Word: 'potential': number of entries: 1.
# 	Word: 'call': number of entries: 2.
# 	Word: 'silicon': number of entries: 1.
# 	Word: 'valley': number of entries: 1.
# 	Word: 'europe': number of entries: 3.
# 	Word: 'lead': number of entries: 2.
# 	Word: 'base': number of entries: 1.
# 	Word: 'cluster': number of entries: 2.
# 	Word: 'appear': number of entries: 1.
# 	Word: 'software': number of entries: 2.
# 	Word: 'produce': number of entries: 3.
# 	Word: 'resident': number of entries: 3.
# 	Word: 'company': number of entries: 10.
# 	Word: 'demand': number of entries: 1.
# 	Word: 'abroad': number of entries: 1.
# 	Word: 'coca': number of entries: 1.
# 	Word: 'cola': number of entries: 1.
# 	Word: 'microsoft': number of entries: 1.
# 	Word: 'google': number of entries: 1.
# 	Word: 'toyota': number of entries: 1.
# 	Word: 'mtv': number of entries: 1.
# 	Word: 'reuters': number of entries: 1.
# 	Word: 'samsung': number of entries: 1.
# 	Word: 'mitsubishi': number of entries: 1.
# 	Word: 'british': number of entries: 1.
# 	Word: 'telecom': number of entries: 1.
# 	Word: 'bank': number of entries: 1.
# 	Word: 'include': number of entries: 2.
# 	Word: 'providers': number of entries: 1.
# 	Word: 'services': number of entries: 1.
# 	Word: 'list': number of entries: 1.
# 	Word: 'number': number of entries: 3.
# 	Word: 'exporter': number of entries: 1.
# 	Word: 'cis': number of entries: 2.
# 	Word: 'oao': number of entries: 2.
# 	Word: 'peleng': number of entries: 3.
# 	Word: 'developer': number of entries: 2.
# 	Word: 'optical': number of entries: 1.
# 	Word: 'device': number of entries: 1.
# 	Word: 'optoelectronic': number of entries: 1.
# 	Word: 'military': number of entries: 1.
# 	Word: 'dual': number of entries: 1.
# 	Word: 'use': number of entries: 2.
# 	Word: 'exclusive': number of entries: 1.
# 	Word: 'space': number of entries: 3.
# 	Word: 'equipment': number of entries: 2.
# 	Word: 'july': number of entries: 1.
# 	Word: 'satellite': number of entries: 8.
# 	Word: 'remote': number of entries: 1.
# 	Word: 'sensing': number of entries: 1.
# 	Word: 'earth': number of entries: 2.
# 	Word: 'launch': number of entries: 2.
# 	Word: 'outer': number of entries: 1.
# 	Word: 'soyuz': number of entries: 1.
# 	Word: 'fg': number of entries: 1.
# 	Word: 'booster': number of entries: 1.
# 	Word: 'rocket': number of entries: 1.
# 	Word: 'baikonur': number of entries: 1.
# 	Word: 'site': number of entries: 1.
# 	Word: 'relocate': number of entries: 1.
# 	Word: 'orbit': number of entries: 1.
# 	Word: 'image': number of entries: 1.
# 	Word: 'require': number of entries: 1.
# 	Word: 'angle': number of entries: 1.
# 	Word: 'fit': number of entries: 1.
# 	Word: 'work': number of entries: 3.
# 	Word: 'jointly': number of entries: 1.
# 	Word: 'russian': number of entries: 2.
# 	Word: 'canopus': number of entries: 1.
# 	Word: 'b': number of entries: 1.
# 	Word: 'skif': number of entries: 1.
# 	Word: 'grid': number of entries: 1.
# 	Word: 'supercomputer': number of entries: 1.
# 	Word: 'basis': number of entries: 1.
# 	Word: 'core': number of entries: 1.
# 	Word: 'amd': number of entries: 1.
# 	Word: 'opteron': number of entries: 1.
# 	Word: 'processor': number of entries: 1.
# 	Word: 'graphic': number of entries: 1.
# 	Word: 'processing': number of entries: 1.
# 	Word: 'unit': number of entries: 1.
# 	Word: 'active': number of entries: 1.
# 	Word: 'telecommunication': number of entries: 2.
# 	Word: 'banking': number of entries: 1.
# 	Word: 'forum': number of entries: 4.
# 	Word: 'tibo': number of entries: 1.
# 	Word: 'major': number of entries: 1.
# 	Word: 'event': number of entries: 2.
# 	Word: 'baltic': number of entries: 1.
# 	Word: 'states': number of entries: 1.
# 	Word: 'participant': number of entries: 1.
# 	Word: 'russia': number of entries: 2.
# 	Word: 'latin': number of entries: 1.
# 	Word: 'america': number of entries: 1.
# 	Word: 'asia': number of entries: 1.
# 	Word: 'present': number of entries: 2.
# 	Word: 'interesting': number of entries: 1.
# 	Word: 'medium': number of entries: 2.
# 	Word: 'project': number of entries: 3.
# 	Word: 'modern': number of entries: 2.
# 	Word: 'mass': number of entries: 1.
# 	Word: 'program': number of entries: 1.
# 	Word: 'master': number of entries: 1.
# 	Word: 'class': number of entries: 1.
# 	Word: 'famous': number of entries: 2.
# 	Word: 'media': number of entries: 2.
# 	Word: 'person': number of entries: 1.
# 	Word: 'presentation': number of entries: 1.
# 	Word: 'periodical': number of entries: 1.
# 	Word: 'tv': number of entries: 1.
# 	Word: 'channel': number of entries: 2.
# 	Word: 'radio': number of entries: 1.
# 	Word: 'website': number of entries: 1.
# 	Word: 'unique': number of entries: 2.
# 	Word: 'chip': number of entries: 1.
# 	Word: 'expert': number of entries: 1.
# 	Word: 'ordinary': number of entries: 1.
# 	Word: 'buyer': number of entries: 2.
# 	Word: 'learn': number of entries: 2.
# 	Word: 'product': number of entries: 4.
# 	Word: 'flash': number of entries: 1.
# 	Word: 'passport': number of entries: 1.
# 	Word: 'test': number of entries: 1.
# 	Word: 'producer': number of entries: 1.
# 	Word: 'expensive': number of entries: 1.
# 	Word: 'fur': number of entries: 1.
# 	Word: 'minute': number of entries: 1.
# 	Word: 'file': number of entries: 1.
# 	Word: 'choose': number of entries: 2.
# 	Word: 'screen': number of entries: 1.
# 	Word: 'mobile': number of entries: 3.
# 	Word: 'phone': number of entries: 3.
# 	Word: 'quality': number of entries: 1.
# 	Word: 'origin': number of entries: 1.
# 	Word: 'place': number of entries: 1.
# 	Word: 'production': number of entries: 1.
# 	Word: 'annually': number of entries: 1.
# 	Word: 'implement': number of entries: 1.
# 	Word: 'bilateral': number of entries: 2.
# 	Word: 'character': number of entries: 1.
# 	Word: 'support': number of entries: 2.
# 	Word: 'bi': number of entries: 1.
# 	Word: 'lateral': number of entries: 1.
# 	Word: 'latvia': number of entries: 1.
# 	Word: 'lithuania': number of entries: 1.
# 	Word: 'ukraine': number of entries: 1.
# 	Word: 'poland': number of entries: 1.
# 	Word: 'moldova': number of entries: 1.
# 	Word: 'kazakhstan': number of entries: 1.
# 	Word: 'serbia': number of entries: 1.
# 	Word: 'china': number of entries: 1.
# 	Word: 'india': number of entries: 1.
# 	Word: 'venezuela': number of entries: 1.
# 	Word: 'host': number of entries: 2.
# 	Word: 'technological': number of entries: 1.
# 	Word: 'polytechnic': number of entries: 1.
# 	Word: 'technical': number of entries: 2.
# 	Word: 'south': number of entries: 1.
# 	Word: 'korean': number of entries: 1.
# 	Word: 'successful': number of entries: 1.
# 	Word: 'viber': number of entries: 7.
# 	Word: 'tanks': number of entries: 2.
# 	Word: 'wot': number of entries: 6.
# 	Word: 'recognizable': number of entries: 1.
# 	Word: 'miracle': number of entries: 1.
# 	Word: 'instant': number of entries: 1.
# 	Word: 'messaging': number of entries: 1.
# 	Word: 'voice': number of entries: 2.
# 	Word: 'ip': number of entries: 1.
# 	Word: 'application': number of entries: 2.
# 	Word: 'smartphone': number of entries: 1.
# 	Word: 'exchange': number of entries: 1.
# 	Word: 'video': number of entries: 1.
# 	Word: 'audio': number of entries: 1.
# 	Word: 'message': number of entries: 1.
# 	Word: 'found': number of entries: 1.
# 	Word: 'israeli': number of entries: 1.
# 	Word: 'partner': number of entries: 1.
# 	Word: 'talmon': number of entries: 1.
# 	Word: 'marko': number of entries: 1.
# 	Word: 'igor': number of entries: 1.
# 	Word: 'magazinnik': number of entries: 1.
# 	Word: 'run': number of entries: 1.
# 	Word: 'israel': number of entries: 1.
# 	Word: 'start': number of entries: 1.
# 	Word: 'firm': number of entries: 1.
# 	Word: 'people': number of entries: 1.
# 	Word: 'founder': number of entries: 1.
# 	Word: 'sergei': number of entries: 1.
# 	Word: 'goncharic': number of entries: 1.
# 	Word: 'nowadays': number of entries: 1.
# 	Word: 'leader': number of entries: 1.
# 	Word: 'social': number of entries: 1.
# 	Word: 'category': number of entries: 1.
# 	Word: 'appstores': number of entries: 1.
# 	Word: 'million': number of entries: 3.
# 	Word: 'global': number of entries: 1.
# 	Word: 'registered': number of entries: 1.
# 	Word: 'user': number of entries: 2.
# 	Word: 'cypriot': number of entries: 1.
# 	Word: 'wargame': number of entries: 1.
# 	Word: 'massively': number of entries: 1.
# 	Word: 'multiplayer': number of entries: 1.
# 	Word: 'online': number of entries: 3.
# 	Word: 'game': number of entries: 8.
# 	Word: 'stream': number of entries: 2.
# 	Word: 'minsk': number of entries: 2.
# 	Word: 'wargaming': number of entries: 1.
# 	Word: 'provide': number of entries: 1.
# 	Word: 'organize': number of entries: 1.
# 	Word: 'officially': number of entries: 3.
# 	Word: 'announce': number of entries: 1.
# 	Word: 'august': number of entries: 1.
# 	Word: 'version': number of entries: 1.
# 	Word: 'release': number of entries: 1.
# 	Word: 'player': number of entries: 3.
# 	Word: 'primary': number of entries: 1.
# 	Word: 'type': number of entries: 2.
# 	Word: 'battle': number of entries: 1.
# 	Word: 'single': number of entries: 1.
# 	Word: 'armoured': number of entries: 1.
# 	Word: 'vehicle': number of entries: 2.
# 	Word: 'communicate': number of entries: 1.
# 	Word: 'chat': number of entries: 1.
# 	Word: 'reach': number of entries: 1.
# 	Word: 'january': number of entries: 1.
# 	Word: 'record': number of entries: 1.
# 	Word: 'players': number of entries: 1.
# 	Word: 'simultaneously': number of entries: 1.
# 	Word: 'register': number of entries: 1.
# 	Word: 'guinness': number of entries: 1.
# 	Word: 'book': number of entries: 1.
# 	Word: 'records': number of entries: 1.
# 	Word: 'improve': number of entries: 2.
# 	Word: 'feature': number of entries: 1.
# 	Word: 'add': number of entries: 1.
# 	Word: 'debut': number of entries: 1.
# 	Word: 'esports': number of entries: 1.
# 	Word: 'cyber': number of entries: 1.
# 	Word: 'games': number of entries: 1.
# 	Word: 'name': number of entries: 1.
# 	Word: 'year': number of entries: 1.
# 	Word: 'get': number of entries: 2.
# 	Word: 'golden': number of entries: 1.
# 	Word: 'joystick': number of entries: 1.
# 	Word: 'award': number of entries: 1.
# 	Word: 'today': number of entries: 1.
# 	Word: 'fan': number of entries: 1.
# 	Word: 'exceed': number of entries: 1.
# 	Word: 'nobel': number of entries: 2.
# 	Word: 'prize': number of entries: 2.
# 	Word: 'winner': number of entries: 1.
# 	Word: 'zhore': number of entries: 1.
# 	Word: 'ivanovich': number of entries: 1.
# 	Word: 'alferov': number of entries: 6.
# 	Word: 'bear': number of entries: 1.
# 	Word: 'march': number of entries: 1.
# 	Word: 'vitebsk': number of entries: 1.
# 	Word: 'family': number of entries: 1.
# 	Word: 'factory': number of entries: 1.
# 	Word: 'manager': number of entries: 1.
# 	Word: 'finish': number of entries: 1.
# 	Word: 'school': number of entries: 1.
# 	Word: 'enter': number of entries: 1.
# 	Word: 'politechnic': number of entries: 1.
# 	Word: 'graduate': number of entries: 1.
# 	Word: 'leningrad': number of entries: 1.
# 	Word: 'electrotechnical': number of entries: 1.
# 	Word: 'institute': number of entries: 3.
# 	Word: 'begin': number of entries: 1.
# 	Word: 'ioffe': number of entries: 1.
# 	Word: 'physico': number of entries: 1.
# 	Word: 'degree': number of entries: 1.
# 	Word: 'zhores': number of entries: 2.
# 	Word: 'director': number of entries: 1.
# 	Word: 'invent': number of entries: 1.
# 	Word: 'heterotransistor': number of entries: 1.
# 	Word: 'revolutionize': number of entries: 1.
# 	Word: 'communication': number of entries: 1.
# 	Word: 'turn': number of entries: 1.
# 	Word: 'semiconductor': number of entries: 1.
# 	Word: 'design': number of entries: 1.
# 	Word: 'led': number of entries: 1.
# 	Word: 'cd': number of entries: 2.
# 	Word: 'receive': number of entries: 1.
# 	Word: 'herbert': number of entries: 1.
# 	Word: 'kroemer': number of entries: 1.
# 	Word: 'jack': number of entries: 1.
# 	Word: 'kilby': number of entries: 1.
# 	Word: 'lay': number of entries: 1.
# 	Word: 'foundation': number of entries: 1.
# 	Word: 'era': number of entries: 1.
# 	Word: 'invention': number of entries: 1.
# 	Word: 'transfer': number of entries: 1.
# 	Word: 'telephone': number of entries: 1.
# 	Word: 'line': number of entries: 1.
# 	Word: 'city': number of entries: 1.
# 	Word: 'everyday': number of entries: 1.
# 	Word: 'life': number of entries: 1.
# 	Word: 'traffic': number of entries: 1.
# 	Word: 'light': number of entries: 1.
# 	Word: 'price': number of entries: 1.
# 	Word: 'tag': number of entries: 1.
# 	Word: 'decoder': number of entries: 1.

# %% [markdown]
# ### 9. Выводим _N_ наиболее часто встречаемых слов в тексте:

# %%
N = 10
popular_words = sorted(words_stat.items(), key=lambda item: item[1], reverse=True)[:N]

print(f"{N} наиболее часто встречаемых слов в тексте:")
for word, cnt in popular_words:
    print(f"\tWord: '{word}': number of entries: {cnt}.")
# Out:
# 10 наиболее часто встречаемых слов в тексте:
# 	Word: 'belarusian': number of entries: 19.
# 	Word: 'belarus': number of entries: 14.
# 	Word: 'company': number of entries: 10.
# 	Word: 'scientist': number of entries: 8.
# 	Word: 'world': number of entries: 8.
# 	Word: 'satellite': number of entries: 8.
# 	Word: 'game': number of entries: 8.
# 	Word: 'technology': number of entries: 7.
# 	Word: 'viber': number of entries: 7.
# 	Word: 'information': number of entries: 6.
